# %% [markdown]
# <a href="https://colab.research.google.com/github/23b2232/Titanic_survival/blob/main/Titanic_survival.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
titanic.describe(include='number')
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include='object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
titanic.survived.value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
sns.countplot(x='survived', data=titanic, ax=axes[0][0])
sns.countplot(x='pclass', data=titanic, ax=axes[0][1])
sns.countplot(x='parch', data=titanic, ax=axes[0][2])
sns.countplot(x='sibsp', data=titanic, ax=axes[0][3])
sns.countplot(x='embarked', data=titanic, ax=axes[1][0])
sns.countplot(x='alone', data=titanic, ax=axes[1][1])
sns.countplot(x='deck', data=titanic, ax=axes[1][2])
sns.displot(titanic['fare'], kde=True, ax=axes[1][3])
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
titanic['sex'].value_counts().plot(kind='bar')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(titanic['age'].dropna(), kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
sns.countplot(x='sex', hue='survived', data=titanic)
plt.title('Survival according to the Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
titanic.groupby('pclass')['survived'].mean().plot(kind='barh', ax=axes[0,0], xlim=[0,1])
titanic.groupby('parch')['survived'].mean().plot(kind='barh', ax=axes[0,1], xlim=[0,1])
titanic.groupby('sibsp')['survived'].mean().plot(kind='barh', ax=axes[0,2], xlim=[0,1])
titanic.groupby('alone')['survived'].mean().plot(kind='barh', ax=axes[0,3], xlim=[0,1])
titanic.groupby('embarked')['survived'].mean().plot(kind='barh', ax=axes[1,0], xlim=[0,1])
titanic.groupby('deck')['survived'].mean().plot(kind='barh', ax=axes[1,1], xlim=[0,1])
sns.boxplot(x='survived', y='age', data=titanic, ax=axes[1,2])
sns.boxplot(x='survived', y='fare', data=titanic, ax=axes[1,3])
plt.show()
# Out:
# /tmp/ipython-input-16-1030189150.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby('deck')['survived'].mean().plot(kind='barh', ax=axes[1,1], xlim=[0,1])

# %%
sns.scatterplot(x='age', y='fare', hue='survived', data=titanic)
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True), annot=True, cmap='coolwarm') # annot means annotate the heatmap each number will be shown inside the cell
plt.show()

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].mean())

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# titanic = titanic.drop(columns = ['deck', 'cabin']) \\
# Above code is for deleting columns.

# %%
titanic = titanic.dropna()

# %%
titanic.nunique()
# Out:
# survived        2
# pclass          3
# sex             2
# age            64
# sibsp           4
# parch           4
# fare           99
# embarked        3
# class           3
# who             3
# adult_male      2
# deck            7
# embark_town     3
# alive           2
# alone           2
# dtype: int64

# %%
titanic.count()
# Out:
# survived       201
# pclass         201
# sex            201
# age            201
# sibsp          201
# parch          201
# fare           201
# embarked       201
# class          201
# who            201
# adult_male     201
# deck           201
# embark_town    201
# alive          201
# alone          201
# dtype: int64

# %%
titanic['rich'] = titanic['fare'] > 250

# %%
titanic['rich']
# Out:
# 1      False
# 3      False
# 6      False
# 10     False
# 11     False
#        ...
# 871    False
# 872    False
# 879    False
# 887    False
# 889    False
# Name: rich, Length: 201, dtype: bool

# %%
titanic['sex'] = titanic['sex'].map({'male':0, 'female':1})

# %%
titanic[titanic['fare'] > 250]
# Out:
#      survived  pclass  sex   age  sibsp  parch      fare embarked  class  \
# 27          0       1    0  19.0      3      2  263.0000        S  First
# 88          1       1    1  23.0      3      2  263.0000        S  First
# 311         1       1    1  18.0      2      2  262.3750        C  First
# 341         1       1    1  24.0      3      2  263.0000        S  First
# 438         0       1    0  64.0      1      4  263.0000        S  First
# 679         1       1    0  36.0      0      1  512.3292        C  First
# 737         1       1    0  35.0      0      0  512.3292        C  First
# 742         1       1    1  21.0      2      2  262.3750        C  First
#
#        who  adult_male deck  embark_town alive  alone  rich
# 27     man        True    C  Southampton    no  False  True
# 88   woman       False    C  Southampton   yes  False  True
# 311  woman       False    B    Cherbourg   yes  False  True
# 341  woman       False    C  Southampton   yes  False  True
# ...

# %%
sns.boxplot(x=titanic['fare'])
plt.show()

# %%
print((titanic['fare']==0).sum())
# Out:
# 3

# %%
titanic['fare'] = titanic['fare'].replace(0, np.nan)

# %%
print((titanic['fare']==0).sum())
# Out:
# 0

# %%
titanic[titanic.fare.isnull()].index
# Out:
# Index([263, 806, 815], dtype='int64')

# %%
titanic.fare.mean()
# Out:
# np.float64(77.46144848484849)

# %%
titanic.fare.fillna(titanic.fare.mean(), inplace=True)
# Out:
# /tmp/ipython-input-35-106993635.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.fare.fillna(titanic.fare.mean(), inplace=True)

# %%
titanic.fare.isnull().sum()
# Out:
# np.int64(0)

# %%
titanic.deck.isnull().sum()
# Out:
# np.int64(0)

# %%
titanic.deck.isnull().mean()
# Out:
# np.float64(0.0)

# %%
import missingno as msno

# %%
msno.matrix(titanic)
# Out:
# <Axes: >

# %%
msno.heatmap(titanic)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %%
fare = titanic['fare'].dropna()

# %%
from scipy.stats import skew, kurtosis
print(skew(fare))
print(kurtosis(fare))
# Out:
# 2.7400896447503174
# 10.871600648582827

# %% [markdown]
# The following is the model implementation from scratch and some already dervued ones. The models included are: Logistic Regression, Naive Bayes

# %%
# Logistic Regression
titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-128-908123090.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['embarked'].fillna(titanic['embarked'].mode()[0], inplace=True)

# %%
titanic['sex'] = titanic['sex'].map({'male':0, 'female':1})
titanic = pd.get_dummies(titanic, columns=['embarked'], drop_first=True)

# %%
X = titanic[['age', 'fare', 'sex', 'pclass', 'sibsp', 'parch', 'embarked_Q', 'embarked_S']].values
y = titanic['survived'].values

# %%
class LogisticRegression:

    def __init__(self, lr=0.001, n_iters=1000):
        self.lr = lr
        self.n_iters = n_iters
        self.weights = None
        self.bias = None


    def fit(self, X, y):
        n_samples, n_features = X.shape

        # init parameters
        self.weights = np.zeros(n_features)
        self.bias = 0

        # gradient descent
        for _ in range(self.n_iters):
            linear_model = np.dot(X, self.weights) + self.bias
            y_predicted = self.sigmoid(linear_model)

            dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1 / n_samples) * np.sum(y_predicted - y)

            self.weights -= self.lr * dw
            self.bias -= self.lr * db


    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self.sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return y_predicted_cls


    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

# %%
# Naive Bayes Theorem

# %%
# LDA

# %%
# KNN
